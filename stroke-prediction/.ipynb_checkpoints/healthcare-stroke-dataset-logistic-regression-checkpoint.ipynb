# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import csv
from pandas import DataFrame 
from datetime import datetime
from dateutil.relativedelta import relativedelta
import time
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
data_train = pd.read_csv('train_2v.csv',low_memory=False,skipinitialspace=True)
data_test = pd.read_csv('test_2v.csv',low_memory=False,skipinitialspace=True)

# %%
print(data_test.shape)
print(data_train.shape)
print(data_test.columns)
print(data_train.columns)
# Out:
# (18601, 11)
# (43400, 12)
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %% [markdown]
# **Since there is no stroke column available in test dataset , considering only Train dataset for whole analysis**

# %%
data_stroke =data_train

# %%
data_stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data_stroke.isnull().sum()
# Out:
# id                       0
# gender                   0
# age                      0
# hypertension             0
# heart_disease            0
# ever_married             0
# work_type                0
# Residence_type           0
# avg_glucose_level        0
# bmi                   1462
# smoking_status       13292
# stroke                   0
# dtype: int64

# %% [markdown]
# **EDA on dataset**

# %%
sns.heatmap(data_stroke.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# **A countplot shows the counts of observations in each categorical bin using bars.**

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.countplot(x="stroke", data=data_stroke, color="c")
plt.show()

# %%
data_stroke['age'].hist(bins=100)

# %%
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==1), 
            'age'], color='r', shade=True, Label='Stroke') 
  
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==0),  
            'age'], color='b', shade=True, Label='No Stroke') 
  
plt.xlabel('Age') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==1), 
            'avg_glucose_level'], color='r', shade=True, Label='Stroke') 
  
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==0),  
            'avg_glucose_level'], color='b', shade=True, Label='No Stroke') 
  
plt.xlabel('Avg_glucose_level') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==1), 
            'hypertension'], color='r', shade=True, Label='Stroke', bw=1) 
  
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==0),  
            'hypertension'], color='b', shade=True, Label='No Stroke', bw=1) 
  
plt.xlabel('hypertension') 
plt.ylabel('Probability Density') 

#sns.kdeplot(ser_test, cumulative=True, bw=1.5)
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==1), 
            'bmi'], color='r', shade=True, Label='Stroke') 
  
sns.kdeplot(data_stroke.loc[(data_stroke['stroke']==0),  
            'bmi'], color='b', shade=True, Label='No Stroke') 
  
plt.xlabel('Body Mass Index') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# **Handling Missing Data**

# %%
data_stroke['bmi'].fillna(data_stroke['bmi'].mean(),inplace=True)

# %% [markdown]
# **Handling the Categorical columns**

# %%
from sklearn.preprocessing import LabelEncoder
# instantiate labelencoder object
labelEncoder = LabelEncoder()
data_stroke['gender'] = labelEncoder.fit_transform(data_stroke['gender'])
data_stroke['ever_married'] = labelEncoder.fit_transform(data_stroke['ever_married'])
data_stroke['work_type'] = labelEncoder.fit_transform(data_stroke['work_type'])
data_stroke['Residence_type'] = labelEncoder.fit_transform(data_stroke['Residence_type'])

# %%
data_stroke.isnull().sum()
# Out:
# id                       0
# gender                   0
# age                      0
# hypertension             0
# heart_disease            0
# ever_married             0
# work_type                0
# Residence_type           0
# avg_glucose_level        0
# bmi                      0
# smoking_status       13292
# stroke                   0
# dtype: int64

# %%
print(data_stroke.smoking_status.value_counts())
print(data_stroke[data_stroke.smoking_status.isnull()]['stroke'].value_counts())
# Out:
# never smoked       16053
# formerly smoked     7493
# smokes              6562
# Name: smoking_status, dtype: int64
# 0    13147
# 1      145
# Name: stroke, dtype: int64

# %% [markdown]
# ** Dropping the smoking_status column , Since 30% of data is missing**

# %%
data_stroke.drop('smoking_status',axis = 1, inplace = True)

# %% [markdown]
# **ID column is not required in this Logistic Regression Prediction **

# %%
data_stroke.drop('id',axis = 1, inplace = True)

# %%
data_stroke.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# stroke               0
# dtype: int64

# %% [markdown]
# **UnderSampling technique**
#
# since the data is imbalanced , the undersampling technique is processed

# %%
data_shuffled = data_stroke.sample(frac=1,random_state=4)
df_Isstroke = data_stroke.loc[data_stroke['stroke'] == 1]
df_Nostroke = data_stroke.loc[data_stroke['stroke'] == 0].sample(n= 4500,random_state= 101)

# %%
df_data_stroke = pd.concat([df_Isstroke,df_Nostroke])

# %%
df_data_stroke.stroke.value_counts()
# Out:
# 0    4500
# 1     783
# Name: stroke, dtype: int64

# %% [markdown]
# **Split the data as train and test**

# %%
from sklearn.model_selection import train_test_split 
from sklearn.utils import shuffle
df_data_stroke = shuffle(df_data_stroke)
X = df_data_stroke.drop('stroke', axis = 1)
y = df_data_stroke['stroke']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
print('X Train dataset shapes',X_train.shape)
print('Y Train dataset shapes',y_train.shape)
print('X Test dataset shapes',X_test.shape)
print('Y Test dataset shapes',y_test.shape)
# Out:
# X Train dataset shapes (3698, 9)
# Y Train dataset shapes (3698,)
# X Test dataset shapes (1585, 9)
# Y Test dataset shapes (1585,)

# %% [markdown]
# **Applying Logistic Regression Model**

# %%
from sklearn.linear_model import LogisticRegression

# %%
logRe = LogisticRegression()
logRe.fit(X_train,y_train)
# Out:
# /home/monad/anaconda3/envs/tff/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions = logRe.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
print(classification_report(y_test,predictions))
logRe.score(X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1336
#            1       0.60      0.23      0.34       249
#
#    micro avg       0.85      0.85      0.85      1585
#    macro avg       0.73      0.60      0.63      1585
# weighted avg       0.83      0.85      0.83      1585
# 0.8548895899053628

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[1297   39]
#  [ 191   58]]

# %%
from sklearn import metrics
sns.heatmap(confusion_matrix(y_test,predictions), annot= True, fmt=".2f")
plt.title('Logistic Regression \n Confusion Matrix', fontsize=14)
print(roc_auc_score(y_test, predictions))
# Out:
# 0.6018700550705817

# %%
test_stroke = y_test.values
for i in range(0, len(test_stroke)):
    if predictions[i] == test_stroke[i]:
        print ('Pred: {0} Actual:{1}'.format(predictions[i], test_stroke[i]))
    else:
        print('Wrong Prediction')
        print ('Pred: {0} Actual:{1}'.format(predictions[i], test_stroke[i]))
# Out:
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 0 Actual:1
# Wrong Prediction
# Pred: 1 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 1 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1
# Pred: 0 Actual:0
# Wrong Prediction
# Pred: 0 Actual:1

# %% [markdown]
# **StatsModel api- LogisticRegression **

# %%
import statsmodels.api as sm

logit_model = sm.Logit(y_train,sm.add_constant(X_train))

# %%
result = logit_model.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.306885
#          Iterations 8

# %%
print(result.summary2())
# Out:
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.257
# Dependent Variable: stroke           AIC:              2289.7212
# Date:               2020-03-25 00:47 BIC:              2351.8767
# No. Observations:   3698             Log-Likelihood:   -1134.9
# Df Model:           9                LL-Null:          -1526.8
# Df Residuals:       3688             LLR p-value:      6.1927e-163
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     8.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# const             -6.2762   0.4048 -15.5034 0.0000 -7.0696 -5.4827
# gender             0.0573   0.1091   0.5254 0.5993 -0.1565  0.2710
# age                0.0685   0.0039  17.3936 0.0000  0.0608  0.0762
# hypertension       0.4691   0.1319   3.5563 0.0004  0.2106  0.7276
# heart_disease      0.7891   0.1526   5.1703 0.0000  0.4900  1.0883
# ever_married      -0.1288   0.1795  -0.7173 0.4732 -0.4806  0.2231
# work_type          0.0728   0.0603   1.2089 0.2267 -0.0453  0.1909
# Residence_type     0.1489   0.1069   1.3928 0.1637 -0.0606  0.3584
# avg_glucose_level  0.0038   0.0010   3.8900 0.0001  0.0019  0.0057
# bmi               -0.0055   0.0086  -0.6384 0.5232 -0.0223  0.0113
# ==================================================================

# %% [markdown]
# **Get the significant variables from logit model**

# %%
def get_significant_vars(lm):
    #Store the pvalues to corresponding columns
    df_p_vals = pd.DataFrame(lm.pvalues)
    df_p_vals['vars'] = df_p_vals.index
    df_p_vals.columns=['p_values','variables']
    return list(df_p_vals[df_p_vals['p_values']<=0.05]['variables'])

# %%
significant_var= get_significant_vars(result)
print(significant_var)
# Out:
# ['const', 'age', 'hypertension', 'heart_disease', 'avg_glucose_level']

# %%
if 'const' in significant_var:
    significant_var.remove('const')
    logit_model1 = sm.Logit(y_train,sm.add_constant(X_train[significant_var]))

# %%
final_logit = logit_model1.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.307553
#          Iterations 8

# %%
print(final_logit.summary2())
# Out:
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.255
# Dependent Variable: stroke           AIC:              2284.6634
# Date:               2020-03-25 00:47 BIC:              2315.7411
# No. Observations:   3698             Log-Likelihood:   -1137.3
# Df Model:           4                LL-Null:          -1526.8
# Df Residuals:       3693             LLR p-value:      2.7676e-167
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     8.0000
# ------------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ------------------------------------------------------------------
# const             -6.2858   0.2659 -23.6383 0.0000 -6.8070 -5.7646
# age                0.0685   0.0038  17.9344 0.0000  0.0610  0.0759
# hypertension       0.4752   0.1307   3.6347 0.0003  0.2190  0.7315
# heart_disease      0.8058   0.1507   5.3467 0.0000  0.5104  1.1011
# avg_glucose_level  0.0036   0.0010   3.8068 0.0001  0.0018  0.0055
# ==================================================================

# %%
# cols_significant = significant_var.remove('const')

print(X_test[significant_var].columns)
result =final_logit.predict(sm.add_constant(X_test[significant_var]))
Y_pred_df= pd.DataFrame({"actuals":y_test,"predicted_prob":result})
Y_pred_df.sample(100,random_state=50)
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level'], dtype='object')
#        actuals  predicted_prob
# 40359        1        0.164332
# 26539        0        0.124214
# 24662        0        0.032092
# 15159        0        0.010916
# 914          0        0.004128
# ...        ...             ...
# 11750        0        0.031201
# 28104        0        0.535442
# 6953         1        0.109259
# 1063         0        0.083597
# 31785        0        0.548621
#
# [100 rows x 2 columns]

# %% [markdown]
# **Optimal classification cut off value**
#
# Lets assume the OCC value us 0.3 as of now

# %%
Y_pred_df['Predicted']= Y_pred_df.predicted_prob.map(lambda x: 1 if x > 0.3 else 0)
Y_pred_df.sample(100,random_state=42)
# Out:
#        actuals  predicted_prob  Predicted
# 20458        0        0.022480          0
# 37388        0        0.006189          0
# 41230        0        0.038098          0
# 24071        0        0.022394          0
# 40170        1        0.261849          0
# ...        ...             ...        ...
# 20231        0        0.695539          1
# 25100        0        0.171125          0
# 39818        0        0.018425          0
# 12360        0        0.028285          0
# 1238         0        0.012014          0
#
# [100 rows x 3 columns]

# %%
def create_cm(actuals, predicted):
    sns.heatmap(confusion_matrix(actuals,predicted), annot= True, fmt=".2f")
    plt.title('Logistic Regression \n Confusion Matrix', fontsize=14)
    plt.ylabel('True Lable')
    plt.xlabel('Predicted Lable')
    plt.show()

# %%
create_cm(Y_pred_df.actuals,Y_pred_df.Predicted)

# %%
print(classification_report(Y_pred_df.actuals,Y_pred_df.Predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      1336
#            1       0.51      0.57      0.54       249
#
#    micro avg       0.85      0.85      0.85      1585
#    macro avg       0.71      0.74      0.72      1585
# weighted avg       0.85      0.85      0.85      1585

# %%
def create_roc_auc(actuals, predicted):
    logit_roc_auc = roc_auc_score(actuals, predicted)
    fpr, tpr, thresholds = roc_curve(actuals, predicted )
    plt.figure()
    plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()

# %%
create_roc_auc(Y_pred_df.actuals,Y_pred_df.Predicted)
